# %% [markdown]
# # Futbolo grafiko analize

# %%
import pandas as pd

# %%
df = pd.read_csv("weather.csv", index_col=0)
df
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Sep          77     57.0        103.0          40               0.17
# Jul          77     58.0        105.0          44               0.00
# Aug          77     59.0        102.0          43               0.03
# Jun          75     56.0        107.0          41               0.11
# Oct          73     54.0         96.0          34               0.81
# May          71     53.0         98.0          35               0.48
# Apr          67     50.0         92.0          28               1.02
# Mar          65     48.0         84.0          25               2.34
# Nov          64     48.0         84.0          30               1.70
# Feb          61     45.0         78.0          26               3.02
# Jan          58     42.0         74.0          22               2.05
# Dec          58     42.0         73.0          21               2.56
# Dec          58      NaN          NaN          21               2.56
#
#        naujas stulpelis  naujas_stulpelis  naujas_stulpelis_2
# month
# Sep                   5                 5                31.5
# Jul                   5                 5                30.5
# Aug                   5                 5                29.5
# Jun                   5                 5                33.0
# Oct                   5                 5                31.0
# May                   5                 5                31.5
# Apr                   5                 5                32.0
# Mar                   5                 5                29.5
# Nov                   5                 5                27.0
# Feb                   5                 5                26.0
# Jan                   5                 5                26.0
# Dec                   5                 5                26.0
# Dec                   5                 5                 NaN

# %%
df = pd.read_csv('LT.csv')
df
# Out:
#            date   home_team  away_team  home_score  away_score  \
# 0    1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1    1979-07-22     Georgia  Lithuania           5           0
# 2    1979-07-24  Azerbaijan  Lithuania           0           1
# 3    1979-07-28   Lithuania    Ukraine           0           2
# 4    1979-07-30      Russia  Lithuania           2           0
# ..          ...         ...        ...         ...         ...
# 362  2019-09-10   Lithuania   Portugal           1           5
# 363  2019-10-11     Ukraine  Lithuania           2           0
# 364  2019-10-11     Ukraine  Lithuania           2           0
# 365  2019-10-14   Lithuania     Serbia           1           2
# 366  2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country
# 0                   Friendly   Moscow  Soviet Union
# 1                   Friendly   Moscow  Soviet Union
# 2                   Friendly   Moscow  Soviet Union
# 3                   Friendly   Moscow  Soviet Union
# 4                   Friendly   Moscow  Soviet Union
# ..                       ...      ...           ...
# 362  UEFA Euro qualification  Vilnius     Lithuania
# 363  UEFA Euro qualification  Kharkiv       Ukraine
# 364  UEFA Euro qualification  Kharkiv       Ukraine
# 365  UEFA Euro qualification  Vilnius     Lithuania
# 366  UEFA Euro qualification  Vilnius     Lithuania
#
# [367 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        367 non-null    object
#  1   home_team   367 non-null    object
#  2   away_team   367 non-null    object
#  3   home_score  367 non-null    int64
#  4   away_score  367 non-null    int64
#  5   tourniment  367 non-null    object
#  6   city        367 non-null    object
#  7   country     367 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 23.1+ KB

# %%
df['date'] = pd.to_datetime(df['date'])
df['home_team'] = pd.Categorical(df['home_team'])
df['away_team'] = pd.Categorical(df['away_team'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        367 non-null    datetime64[ns]
#  1   home_team   367 non-null    category
#  2   away_team   367 non-null    category
#  3   home_score  367 non-null    int64
#  4   away_score  367 non-null    int64
#  5   tourniment  367 non-null    object
#  6   city        367 non-null    object
#  7   country     367 non-null    object
# dtypes: category(2), datetime64[ns](1), int64(2), object(3)
# memory usage: 23.0+ KB

# %%
df.tail(10)
# Out:
#           date  home_team  away_team  home_score  away_score  \
# 357 2019-06-10     Serbia  Lithuania           4           1
# 358 2019-06-10     Serbia  Lithuania           4           1
# 359 2019-09-07  Lithuania    Ukraine           0           3
# 360 2019-09-07  Lithuania    Ukraine           0           3
# 361 2019-09-10  Lithuania   Portugal           1           5
# 362 2019-09-10  Lithuania   Portugal           1           5
# 363 2019-10-11    Ukraine  Lithuania           2           0
# 364 2019-10-11    Ukraine  Lithuania           2           0
# 365 2019-10-14  Lithuania     Serbia           1           2
# 366 2019-10-14  Lithuania     Serbia           1           2
#
#                   tourniment      city    country
# 357  UEFA Euro qualification  Belgrade     Serbia
# 358  UEFA Euro qualification  Belgrade     Serbia
# 359  UEFA Euro qualification   Vilnius  Lithuania
# 360  UEFA Euro qualification   Vilnius  Lithuania
# 361  UEFA Euro qualification   Vilnius  Lithuania
# 362  UEFA Euro qualification   Vilnius  Lithuania
# 363  UEFA Euro qualification   Kharkiv    Ukraine
# 364  UEFA Euro qualification   Kharkiv    Ukraine
# 365  UEFA Euro qualification   Vilnius  Lithuania
# 366  UEFA Euro qualification   Vilnius  Lithuania

# %%
df[ df['away_team'] == 'Lithuania' ]
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 4   1979-07-30      Russia  Lithuania           2           0
# 5   1979-08-01     Belarus  Lithuania           0           2
# ..         ...         ...        ...         ...         ...
# 354 2019-03-25  Azerbaijan  Lithuania           0           0
# 357 2019-06-10      Serbia  Lithuania           4           1
# 358 2019-06-10      Serbia  Lithuania           4           1
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
#
#                   tourniment      city       country
# 0                   Friendly    Moscow  Soviet Union
# 1                   Friendly    Moscow  Soviet Union
# 2                   Friendly    Moscow  Soviet Union
# 4                   Friendly    Moscow  Soviet Union
# 5                   Friendly    Moscow  Soviet Union
# ..                       ...       ...           ...
# 354                 Friendly      Baku    Azerbaijan
# 357  UEFA Euro qualification  Belgrade        Serbia
# 358  UEFA Euro qualification  Belgrade        Serbia
# 363  UEFA Euro qualification   Kharkiv       Ukraine
# 364  UEFA Euro qualification   Kharkiv       Ukraine
#
# [219 rows x 8 columns]

# %%
df['away_team'] == 'Lithuania'  # tai kauke
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 362    False
# 363     True
# 364     True
# 365    False
# 366    False
# Name: away_team, Length: 367, dtype: bool

# %%
df[ (df['away_team'] == 'Lithuania') & (df['city'] == 'Kharkiv') ]
# Out:
#           date home_team  away_team  home_score  away_score  \
# 196 2010-05-25   Ukraine  Lithuania           4           0
# 363 2019-10-11   Ukraine  Lithuania           2           0
# 364 2019-10-11   Ukraine  Lithuania           2           0
#
#                   tourniment     city  country
# 196                 Friendly  Kharkiv  Ukraine
# 363  UEFA Euro qualification  Kharkiv  Ukraine
# 364  UEFA Euro qualification  Kharkiv  Ukraine

# %%
# Bitwise operator
# and &
# or 
# not = ~
# in = .isin ( <sarasas> )

# %%
df[ df['city'].isin( ['Vilnius', 'Kaunas'] ) ]
# Out:
#           date  home_team away_team  home_score  away_score  \
# 17  1992-09-02  Lithuania   Georgia           1           0
# 18  1992-09-23  Lithuania   Denmark           0           0
# 19  1992-10-14  Lithuania  Slovakia           0           1
# 20  1992-10-28  Lithuania    Latvia           1           1
# 26  1993-04-14  Lithuania   Albania           3           1
# ..         ...        ...       ...         ...         ...
# 360 2019-09-07  Lithuania   Ukraine           0           3
# 361 2019-09-10  Lithuania  Portugal           1           5
# 362 2019-09-10  Lithuania  Portugal           1           5
# 365 2019-10-14  Lithuania    Serbia           1           2
# 366 2019-10-14  Lithuania    Serbia           1           2
#
#                        tourniment     city    country
# 17                       Friendly   Kaunas  Lithuania
# 18   FIFA World Cup qualification  Vilnius  Lithuania
# 19                       Friendly  Vilnius  Lithuania
# 20   FIFA World Cup qualification  Vilnius  Lithuania
# 26   FIFA World Cup qualification  Vilnius  Lithuania
# ..                            ...      ...        ...
# 360       UEFA Euro qualification  Vilnius  Lithuania
# 361       UEFA Euro qualification  Vilnius  Lithuania
# 362       UEFA Euro qualification  Vilnius  Lithuania
# 365       UEFA Euro qualification  Vilnius  Lithuania
# 366       UEFA Euro qualification  Vilnius  Lithuania
#
# [121 rows x 8 columns]

# %%
df.loc[ df['city'].isin( ['Vilnius', 'Kaunas'] ) ]
# Out:
#           date  home_team away_team  home_score  away_score  \
# 17  1992-09-02  Lithuania   Georgia           1           0
# 18  1992-09-23  Lithuania   Denmark           0           0
# 19  1992-10-14  Lithuania  Slovakia           0           1
# 20  1992-10-28  Lithuania    Latvia           1           1
# 26  1993-04-14  Lithuania   Albania           3           1
# ..         ...        ...       ...         ...         ...
# 360 2019-09-07  Lithuania   Ukraine           0           3
# 361 2019-09-10  Lithuania  Portugal           1           5
# 362 2019-09-10  Lithuania  Portugal           1           5
# 365 2019-10-14  Lithuania    Serbia           1           2
# 366 2019-10-14  Lithuania    Serbia           1           2
#
#                        tourniment     city    country
# 17                       Friendly   Kaunas  Lithuania
# 18   FIFA World Cup qualification  Vilnius  Lithuania
# 19                       Friendly  Vilnius  Lithuania
# 20   FIFA World Cup qualification  Vilnius  Lithuania
# 26   FIFA World Cup qualification  Vilnius  Lithuania
# ..                            ...      ...        ...
# 360       UEFA Euro qualification  Vilnius  Lithuania
# 361       UEFA Euro qualification  Vilnius  Lithuania
# 362       UEFA Euro qualification  Vilnius  Lithuania
# 365       UEFA Euro qualification  Vilnius  Lithuania
# 366       UEFA Euro qualification  Vilnius  Lithuania
#
# [121 rows x 8 columns]

# %%
df['city'].isin( ['Vilnius', 'Kaunas'] )
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 362     True
# 363    False
# 364    False
# 365     True
# 366     True
# Name: city, Length: 367, dtype: bool

# %%
# Uzduotys

# %%
df[ 'score_sum' ] = df['home_score'] + df['away_score'] 
df
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country  score_sum
# 0                   Friendly   Moscow  Soviet Union          0
# 1                   Friendly   Moscow  Soviet Union          5
# 2                   Friendly   Moscow  Soviet Union          1
# 3                   Friendly   Moscow  Soviet Union          2
# 4                   Friendly   Moscow  Soviet Union          2
# ..                       ...      ...           ...        ...
# 362  UEFA Euro qualification  Vilnius     Lithuania          6
# 363  UEFA Euro qualification  Kharkiv       Ukraine          2
# 364  UEFA Euro qualification  Kharkiv       Ukraine          2
# 365  UEFA Euro qualification  Vilnius     Lithuania          3
# 366  UEFA Euro qualification  Vilnius     Lithuania          3
#
# [367 rows x 9 columns]

# %%
df[ 'score_diff' ] = df['home_score'] - df['away_score'] 
df
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country  score_sum  score_diff
# 0                   Friendly   Moscow  Soviet Union          0           0
# 1                   Friendly   Moscow  Soviet Union          5           5
# 2                   Friendly   Moscow  Soviet Union          1          -1
# 3                   Friendly   Moscow  Soviet Union          2          -2
# 4                   Friendly   Moscow  Soviet Union          2           2
# ..                       ...      ...           ...        ...         ...
# 362  UEFA Euro qualification  Vilnius     Lithuania          6          -4
# 363  UEFA Euro qualification  Kharkiv       Ukraine          2           2
# 364  UEFA Euro qualification  Kharkiv       Ukraine          2           2
# 365  UEFA Euro qualification  Vilnius     Lithuania          3          -1
# 366  UEFA Euro qualification  Vilnius     Lithuania          3          -1
#
# [367 rows x 10 columns]

# %%
df[ df['score_diff'] == 0 ]
# Out:
#           date         home_team   away_team  home_score  away_score  \
# 0   1979-07-20        Kyrgyzstan   Lithuania           0           0
# 7   1990-05-27           Georgia   Lithuania           2           2
# 9   1991-11-17         Lithuania      Latvia           1           1
# 11  1992-04-28  Northern Ireland   Lithuania           2           2
# 12  1992-05-20           Moldova   Lithuania           1           1
# ..         ...               ...         ...         ...         ...
# 334 2018-06-05         Lithuania      Latvia           1           1
# 353 2019-03-25        Azerbaijan   Lithuania           0           0
# 354 2019-03-25        Azerbaijan   Lithuania           0           0
# 355 2019-06-07         Lithuania  Luxembourg           1           1
# 356 2019-06-07         Lithuania  Luxembourg           1           1
#
#                        tourniment      city           country  score_sum  \
# 0                        Friendly    Moscow      Soviet Union          0
# 7                        Friendly   Tbilisi      Soviet Union          4
# 9                      Baltic Cup  Kretinga         Lithuania          2
# 11   FIFA World Cup qualification   Belfast  Northern Ireland          4
# 12                       Friendly  Chi?in?u           Moldova          2
# ..                            ...       ...               ...        ...
# 334                      Friendly   Vilnius         Lithuania          2
# 353                      Friendly      Baku        Azerbaijan          0
# 354                      Friendly      Baku        Azerbaijan          0
# 355       UEFA Euro qualification   Vilnius         Lithuania          2
# 356       UEFA Euro qualification   Vilnius         Lithuania          2
#
#      score_diff
# 0             0
# 7             0
# 9             0
# 11            0
# 12            0
# ..          ...
# 334           0
# 353           0
# 354           0
# 355           0
# 356           0
#
# [73 rows x 10 columns]

# %%
df[ df['home_team'] == 'Lithuania' ].sort_values('score_diff',ascending=True).iloc[0]
# Out:
# date                   2000-10-11 00:00:00
# home_team                        Lithuania
# away_team                          Hungary
# home_score                               1
# away_score                               6
# tourniment    FIFA World Cup qualification
# city                                Kaunas
# country                          Lithuania
# score_sum                                7
# score_diff                              -5
# Name: 108, dtype: object

# %%
len(df[ (df['away_team'] == 'Lithuania') & (df['score_diff'] > 0 ) ] )
# Out:
# 138

# %%
len(df[ (df['away_team'] == 'Lithuania') & (df['score_diff'] < 0 ) ] )
# Out:
# 39

# %%
len(df[ (df['home_team'] == 'Lithuania') & (df['score_diff'] > 0 ) ] )
# Out:
# 49

# %%
len(df[ (df['home_team'] == 'Lithuania') & (df['score_diff'] < 0 ) & (df['country'] == 'Lithuania') ])
# Out:
# 60

# %%
len( df[ (df['home_team'] == 'Lithuania') & (df['score_diff'] == 0 ) ] )
# Out:
# 31

# %%
len( df[ (df['away_team'] == 'Lithuania') & (df['score_diff'] == 0 ) ] )
# Out:
# 42

# %% [markdown]
# # Groupby

# %%
df
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country  score_sum  score_diff
# 0                   Friendly   Moscow  Soviet Union          0           0
# 1                   Friendly   Moscow  Soviet Union          5           5
# 2                   Friendly   Moscow  Soviet Union          1          -1
# 3                   Friendly   Moscow  Soviet Union          2          -2
# 4                   Friendly   Moscow  Soviet Union          2           2
# ..                       ...      ...           ...        ...         ...
# 362  UEFA Euro qualification  Vilnius     Lithuania          6          -4
# 363  UEFA Euro qualification  Kharkiv       Ukraine          2           2
# 364  UEFA Euro qualification  Kharkiv       Ukraine          2           2
# 365  UEFA Euro qualification  Vilnius     Lithuania          3          -1
# 366  UEFA Euro qualification  Vilnius     Lithuania          3          -1
#
# [367 rows x 10 columns]

# %%
df.groupby('home_team').sum()
# Out:
# C:\Users\Ingrida\AppData\Local\Temp\ipykernel_6792\2691750888.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('home_team').sum()
#                         home_score  away_score  score_sum  score_diff
# home_team
# Albania                         10           4         14           6
# Andorra                          1           3          4          -2
# Argentina                        0           0          0           0
# Armenia                          8           6         14           2
# Austria                          6           1          7           5
# Azerbaijan                       2           2          4           0
# Belarus                         10           6         16           4
# Belgium                          1           1          2           0
# Bosnia and Herzegovina           9           1         10           8
# Brazil                           3           1          4           2
# Bulgaria                         3           0          3           3
# Catalonia                        5           0          5           5
# Chile                            1           0          1           1
# Croatia                          2           0          2           2
# Cyprus                           4           3          7           1
# Czech Republic                  15           4         19          11
# Denmark                          4           0          4           4
# England                         12           0         12          12
# Estonia                         17          25         42          -8
# Faroe Islands                    3           6          9          -3
# Finland                          3           2          5           1
# France                           3           0          3           3
# Georgia                         18           4         22          14
# Germany                          1           1          2           0
# Greece                           4           0          4           4
# Hungary                         14           1         15          13
# Iceland                          3           0          3           3
# Israel                           6           3          9           3
# Italy                            9           1         10           8
# Kazakhstan                       2           2          4           0
# Kuwait                           1           0          1           1
# Kyrgyzstan                       0           0          0           0
# Latvia                          40          21         61          19
# Liechtenstein                    4           6         10          -2
# Lithuania                      156         193        349         -37
# Luxembourg                       8           5         13           3
# Malta                            8           7         15           1
# Moldova                          9           7         16           2
# Montenegro                       4           0          4           4
# North Macedonia                  3           2          5           1
# Northern Ireland                 2           2          4           0
# Norway                           3           0          3           3
# Poland                          19           5         24          14
# Portugal                         9           2         11           7
# Republic of Ireland              2           0          2           2
# Romania                         12           3         15           9
# Russia                          14           4         18          10
# San Marino                       0           5          5          -5
# Scotland                        11           3         14           8
# Serbia                          25           5         30          20
# Slovakia                        12           4         16           8
# Slovenia                        11           4         15           7
# Spain                            9           1         10           8
# Sweden                           5           2          7           3
# Switzerland                      8           0          8           8
# Ukraine                         14           4         18          10

# %%
df.groupby('home_team').sum().loc['Lithuania', ['home_score','away_score'] ]
# Out:
# C:\Users\Ingrida\AppData\Local\Temp\ipykernel_6792\3532471973.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('home_team').sum().loc['Lithuania', ['home_score','away_score'] ]
# home_score    156
# away_score    193
# Name: Lithuania, dtype: int64

# %%
import numpy as np

# %%
def myfunction(group_values):

    return len(group_values)

df.groupby('home_team').agg(
    [np.sum, np.mean]
)
# Out:
# C:\Users\Ingrida\AppData\Local\Temp\ipykernel_6792\998742630.py:5: FutureWarning: ['date', 'away_team', 'tourniment', 'city', 'country'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('home_team').agg(
#                        home_score           away_score           score_sum  \
#                               sum      mean        sum      mean       sum
# home_team
# Albania                        10  2.500000          4  1.000000        14
# Andorra                         1  1.000000          3  3.000000         4
# Argentina                       0  0.000000          0  0.000000         0
# Armenia                         8  2.000000          6  1.500000        14
# Austria                         6  3.000000          1  0.500000         7
# Azerbaijan                      2  0.500000          2  0.500000         4
# Belarus                        10  1.666667          6  1.000000        16
# Belgium                         1  1.000000          1  1.000000         2
# Bosnia and Herzegovina          9  2.250000          1  0.250000        10
# Brazil                          3  3.000000          1  1.000000         4
# Bulgaria                        3  3.000000          0  0.000000         3
# Catalonia                       5  5.000000          0  0.000000         5
# Chile                           1  1.000000          0  0.000000         1
# Croatia                         2  2.000000          0  0.000000         2
# Cyprus                          4  1.333333          3  1.000000         7
# Czech Republic                 15  2.500000          4  0.666667        19
# Denmark                         4  4.000000          0  0.000000         4
# England                        12  3.000000          0  0.000000        12
# Estonia                        17  1.000000         25  1.470588        42
# Faroe Islands                   3  0.750000          6  1.500000         9
# Finland                         3  1.000000          2  0.666667         5
# France                          3  1.500000          0  0.000000         3
# Georgia                        18  2.571429          4  0.571429        22
# Germany                         1  1.000000          1  1.000000         2
# Greece                          4  2.000000          0  0.000000         4
# Hungary                        14  2.333333          1  0.166667        15
# Iceland                         3  1.500000          0  0.000000         3
# Israel                          6  3.000000          3  1.500000         9
# Italy                           9  3.000000          1  0.333333        10
# Kazakhstan                      2  1.000000          2  1.000000         4
# Kuwait                          1  1.000000          0  0.000000         1
# Kyrgyzstan                      0  0.000000          0  0.000000         0
# Latvia                         40  1.904762         21  1.000000        61
# Liechtenstein                   4  0.800000          6  1.200000        10
# Lithuania                     156  1.054054        193  1.304054       349
# Luxembourg                      8  1.600000          5  1.000000        13
# Malta                           8  1.333333          7  1.166667        15
# Moldova                         9  1.500000          7  1.166667        16
# Montenegro                      4  2.000000          0  0.000000         4
# North Macedonia                 3  1.000000          2  0.666667         5
# Northern Ireland                2  2.000000          2  2.000000         4
# Norway                          3  1.000000          0  0.000000         3
# Poland                         19  1.900000          5  0.500000        24
# Portugal                        9  4.500000          2  1.000000        11
# Republic of Ireland             2  1.000000          0  0.000000         2
# Romania                        12  1.714286          3  0.428571        15
# Russia                         14  2.800000          4  0.800000        18
# San Marino                      0  0.000000          5  1.666667         5
# Scotland                       11  1.571429          3  0.428571        14
# Serbia                         25  3.571429          5  0.714286        30
# Slovakia                       12  2.400000          4  0.800000        16
# Slovenia                       11  2.200000          4  0.800000        15
# Spain                           9  3.000000          1  0.333333        10
# Sweden                          5  2.500000          2  1.000000         7
# Switzerland                     8  4.000000          0  0.000000         8
# Ukraine                        14  1.750000          4  0.500000        18
#
#                                  score_diff
#                             mean        sum      mean
# home_team
# Albania                 3.500000          6  1.500000
# Andorra                 4.000000         -2 -2.000000
# Argentina               0.000000          0  0.000000
# Armenia                 3.500000          2  0.500000
# Austria                 3.500000          5  2.500000
# Azerbaijan              1.000000          0  0.000000
# Belarus                 2.666667          4  0.666667
# Belgium                 2.000000          0  0.000000
# Bosnia and Herzegovina  2.500000          8  2.000000
# Brazil                  4.000000          2  2.000000
# Bulgaria                3.000000          3  3.000000
# Catalonia               5.000000          5  5.000000
# Chile                   1.000000          1  1.000000
# Croatia                 2.000000          2  2.000000
# Cyprus                  2.333333          1  0.333333
# Czech Republic          3.166667         11  1.833333
# Denmark                 4.000000          4  4.000000
# England                 3.000000         12  3.000000
# Estonia                 2.470588         -8 -0.470588
# Faroe Islands           2.250000         -3 -0.750000
# Finland                 1.666667          1  0.333333
# France                  1.500000          3  1.500000
# Georgia                 3.142857         14  2.000000
# Germany                 2.000000          0  0.000000
# Greece                  2.000000          4  2.000000
# Hungary                 2.500000         13  2.166667
# Iceland                 1.500000          3  1.500000
# Israel                  4.500000          3  1.500000
# Italy                   3.333333          8  2.666667
# Kazakhstan              2.000000          0  0.000000
# Kuwait                  1.000000          1  1.000000
# Kyrgyzstan              0.000000          0  0.000000
# Latvia                  2.904762         19  0.904762
# Liechtenstein           2.000000         -2 -0.400000
# Lithuania               2.358108        -37 -0.250000
# Luxembourg              2.600000          3  0.600000
# Malta                   2.500000          1  0.166667
# Moldova                 2.666667          2  0.333333
# Montenegro              2.000000          4  2.000000
# North Macedonia         1.666667          1  0.333333
# Northern Ireland        4.000000          0  0.000000
# Norway                  1.000000          3  1.000000
# Poland                  2.400000         14  1.400000
# Portugal                5.500000          7  3.500000
# Republic of Ireland     1.000000          2  1.000000
# Romania                 2.142857          9  1.285714
# Russia                  3.600000         10  2.000000
# San Marino              1.666667         -5 -1.666667
# Scotland                2.000000          8  1.142857
# Serbia                  4.285714         20  2.857143
# Slovakia                3.200000          8  1.600000
# Slovenia                3.000000          7  1.400000
# Spain                   3.333333          8  2.666667
# Sweden                  3.500000          3  1.500000
# Switzerland             4.000000          8  4.000000
# Ukraine                 2.250000         10  1.250000

# %%
df = df.rename( columns={'tourniment': 'tournament'})

# %%
# # Kiek ivarciu lietuviai imuse ir praleido zaisdami skirtinguose cempionatuose, zaisdami isvykoje?
# 1. Atsifiltruoti, ten kur lietuviai zaide isvykoje
# 2. Sugrupuoti pagal tournamenta
# 3. Pasirinkti stulpelius home_score ir away_score
# 4. Gale prideti .sum()

# %%
df[ df['away_team'] == 'Lithuania' ].groupby('tournament').sum()[ ['home_score', 'away_score'] ]
# Out:
# C:\Users\Ingrida\AppData\Local\Temp\ipykernel_6792\226702715.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[ df['away_team'] == 'Lithuania' ].groupby('tournament').sum()[ ['home_score', 'away_score'] ]
#                                  home_score  away_score
# tournament
# Baltic Cup                               43          35
# Cyprus International Tournament           8           6
# FIFA World Cup qualification             80          29
# Friendly                                189          67
# Malta International Tournament            1           1
# UEFA Euro qualification                  73          29
# UEFA Nations League                      18           2

# %% [markdown]
# # Merge, join, concatenate

# %%
df_1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
    }
)
df_1
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 3  A3  B3  C3

# %%
df_2 = pd.DataFrame(
    {
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
    }
)
df_2
# Out:
#     A   B   C
# 0  A4  B4  C4
# 1  A5  B5  C5
# 2  A6  B6  C6
# 3  A7  B7  C7

# %%
pd.concat( [df_1, df_2], ignore_index=True )
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 3  A3  B3  C3
# 4  A4  B4  C4
# 5  A5  B5  C5
# 6  A6  B6  C6
# 7  A7  B7  C7

# %%
pd.concat( [df_1, df_2], axis=1 )
# Out:
#     A   B   C   A   B   C
# 0  A0  B0  C0  A4  B4  C4
# 1  A1  B1  C1  A5  B5  C5
# 2  A2  B2  C2  A6  B6  C6
# 3  A3  B3  C3  A7  B7  C7

# %%
left = left.set_index('key')
left

# %%
right = right.set_index('key')
right

# %%
left.join(right)

# %%
left.join(right how='outer')

# %%
pd.merge(left, right, how='left', on='key')

# %%
right

# %%
pd.merge

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np
x = np.arange(0,100)
y = x*5
z = x ** 2

# %%
fig = plt.figure()
ax =  fig.add_axes( (0,0,1,1) )

ax.plot ( x,y )
ax.set_xlabel( 'X asis' )
ax.set_ylabel( 'Y asis' )
ax.set_title( 'Pavadinimas')
# Out:
# Text(0.5, 1.0, 'Pavadinimas')

# %%
fig = plt.figure()
ax =  fig.add_axes( (0,0,1,1) )
print(z[50])
z[49] = 2500
z[50] = 2200

ax.plot ( x, z )
ax_2 = fig.add_axes( (0.3,0.5,0.2,0.2) ) # x_start,y_start,width,height
ax_2.plot( x, z )
ax_2.set_xlim(46,52)
ax_2.set_ylim(2100,2800)
ax_2.spines[['right', 'top']].set_visible(False)
# Out:
# 2200

# %%
fig, axes = plt.subplots( 3,3 )

for row in axes:
    row[2].plot(x,z)
    for col in row:
        col.plot(x,y)

# %%
fig, axes = plt.subplots( 1,2 )

axes[0].plot(x,y, c='b', linewidth=4, linestyle='--')
axes[1].plot(x,z, c='r', linewidth=4, linestyle='-')
